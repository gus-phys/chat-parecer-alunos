# %% [markdown]
# # Exploração de funcionalidades
# ---
# ## Objetivos:
# - [ ] Extração de texto
# - [ ] Implementação da LLM
# - [ ] Criação do banco vetorial

# %% [markdown]
# ---
# # Extração do texto de documentos

# %% [markdown]
# ## Docling

# %%
from docling.document_converter import DocumentConverter

# %%
source = "../data/raw/parecer_alunos.pdf"

# %%
converter = DocumentConverter()
result = converter.convert(source)
# Out:
# 2025-11-06 22:16:51,086 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-11-06 22:16:51,087 - INFO - Going to convert document batch...
# 2025-11-06 22:16:51,087 - INFO - Initializing pipeline for StandardPdfPipeline with options hash f9730ffaa6e7f8d4fb0c98c8df3f18cb
# 2025-11-06 22:16:51,087 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2025-11-06 22:16:51,088 - INFO - easyocr cannot be used because it is not installed.
# 2025-11-06 22:16:51,088 - INFO - Accelerator device: 'cpu'
# [INFO] 2025-11-06 22:16:51,096 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2025-11-06 22:16:51,105 [RapidOCR] download_file.py:60: File exists and is valid: /home/luis/resources/project/chat-parecer-alunos/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# ...

# %%
result.document.export_to_dict().keys()
# Out:
# dict_keys(['schema_name', 'version', 'name', 'origin', 'furniture', 'body', 'groups', 'texts', 'pictures', 'tables', 'key_value_items', 'form_items', 'pages'])

# %%
result.document.export_to_dict()['texts']
# Out:
# [{'self_ref': '#/texts/0',
#   'parent': {'$ref': '#/body'},
#   'children': [],
#   'content_layer': 'body',
#   'label': 'section_header',
#   'prov': [{'page_no': 1,
#     'bbox': {'l': 234.307,
#      't': 768.2140048828126,
#      'r': 364.303,
#      'b': 761.6350048828125,
#      'coord_origin': 'BOTTOMLEFT'},
#     'charspan': [0, 17]}],
#   'orig': 'EDUCAÇÃO INFANTIL',
#   'text': 'EDUCAÇÃO INFANTIL',
#   'level': 1},
#  {'self_ref': '#/texts/1',
#   'parent': {'$ref': '#/body'},
#   'children': [],
#   'content_layer': 'body',
#   'label': 'text',
#   'prov': [{'page_no': 1,
#     'bbox': {'l': 72.0,
#      't': 728.6220048828125,
#      'r': 526.406,
#      'b': 597.8490048828126,
#      'coord_origin': 'BOTTOMLEFT'},
#     'charspan': [0, 671]}],
# ...

# %%
print(result.document.export_to_text())
# Out:
# 2025-11-06 22:32:00,270 - WARNING - Parameter `strict_text` has been deprecated and will be ignored.
# ## EDUCAÇÃO INFANTIL
#
# No   início    do    ano    letivo,    Isaque    chorava    e   mostrava-se   resistente   a   ficar   no   CMEI. Aos    poucos    adaptou-se    aos    colegas,    à    professora    e    à    rotina    do    CMEI.    Às    vezes precisa   ser   lembrado   das   regras   estabelecidas   na   rotina   diária. Diante   de   conflitos, normais   para   a   idade,   geralmente   fica   chateado   e   bate   necessitando   da   orientação da    professora    para    dialogar    com    os    colegas    e    expor    suas    insatisfações.    Recebe estímulos   para   cuidar   dos   seus   pertences,   para   organizá-   los   e   guardá-los   em   seus devidos lugares.
#
# ...
